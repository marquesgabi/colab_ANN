# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import ExcelWriter
from pandas import ExcelFile
# %matplotlib inline

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# funcao normatiza dados
def Normatiza(x):
    strings=['SL','time','TC'] #vou utilizar a normatização somente para essas 3 colunas. variáveis independentes
    for i in strings:
        max_x=x[i].max()
        min_x=x[i].min()
        x_M=(max_x+min_x)/2
        x[i]=(x[i]-x_M)/(max_x-x_M)
    return x

# %%
#path="/home/ucfilho/Documents/Aulas/ANN_2018/Out_03_2018"
#os.chdir(path)

# %%
# !git clone https://github.com/ucfilho/ANN

# %%
# %cd ANN

# %%
DAT=pd.read_csv("Soja_out_03_2018.txt",sep='\t')
print(DAT.head())

# %%
DAT=Normatiza(DAT)
print(DAT.head())

# %%
#writer = ExcelWriter('Soja.xlsx')
#DAT.to_excel(writer,'Sheet1',index=False)
#writer.save()

# %%
X = DAT[['SL','time','TC']]
y= DAT[['MG','WU','Prot']]
print(X.head())
print(y.head())

# %%
formula='MG ~ SL+time+TC+I(SL**2.0)+I(time**2.0)+I(TC**2.0)+I(TC*time)+I(TC*SL)+I(SL*time)' #nome das colunas MG=ganho de massa SL= na proporção sólido para líquido. MG=a+bx1+b2x2+b3x3+c11x1^2+c22x2^2+c33x3^2+c12x1x2+c13x1x3+c23x2x3
est = smf.ols(formula, data=DAT).fit() #est é um objeto
print(est.summary())
